# %%
from madeiras import checagem_completa_longarina_madeira_flexao
if __name__ == "__main__":
    
    # Dados de entrada
    dados_geo = {'b_w': 0.15, 'h': 0.30}
    
    # Chamada da função
    resultado = checagem_completa_longarina_madeira_flexao(
        geo=dados_geo,
        p_gk=2.0,
        p_qk=4.0,
        p_rodak=10.0,
        a=2.0,
        l=5.0,
        classe_carregamento='longa duração',
        classe_madeira='madeira natural',
        classe_umidade=2,
        gamma_g=1.4,
        gamma_q=1.4,
        gamma_w=1.4,
        f_c0k=20000,
        f_t0k=20000,
        f_mk=30000,
        f_vk=4000,
        e_modflex=10000000
    )

    print("\nProcesso concluído!")
# Out:
# /home/joao/miniconda3/envs/uqpy/lib/python3.10/site-packages/UQpy/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# --- Iniciando Cálculo Estrutural ---
# Arquivo Markdown salvo em: /home/joao/Área de trabalho/IC_2025.2/repositorios/reliabridge/Relatorio_Longarina.md
# PDF gerado com sucesso: /home/joao/Área de trabalho/IC_2025.2/repositorios/reliabridge/Relatorio_Longarina.pdf
#
# Processo concluído!
# Verifique os arquivos 'Relatorio_Longarina.md' e '.pdf' na pasta.
